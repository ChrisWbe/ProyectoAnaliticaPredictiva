# %%
# !pip install scikit-learn
# !pip install ipynb

# %%
import pronostic_functions as pf
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pf.obtener_datos(input("Ingrese la ciudad sin tildes: "))
df_metrics = pd.DataFrame(columns=['modelo','mae_train','mae_test','mse_train', 'mse_test'])
df
# Out:
# Ingrese la ciudad sin tildes: medellin
# None
# None
# None
#           fecha  servicios
# 0     1/04/2020        906
# 1     2/04/2020       1013
# 2     3/04/2020       1063
# 3     4/04/2020        953
# 4     5/04/2020        975
# ..          ...        ...
# 388  24/04/2021       1241
# 389  25/04/2021       1253
# 390  26/04/2021       1294
# 391  27/04/2021       1189
# 392  28/04/2021       1235
#
# [393 rows x 2 columns]

# %%
df_metrics = df_metrics.append(pf.model_adaline_optimizado(df),ignore_index=True )
# Out:
# Seleccione el número de inicio para probar P: 6
# Seleccione el número de fin para probar P: 6
# Con P = 6 el error abs promedio de entrenamiento: 128.75, y el error abs promedio de pronóstico: 91.25
# El P óptimo es: 6
# Mean Absolute error test: 91.25
# Mean Absolute error train: 128.75
# Mean Squared error test: 12676.87
# Mean Squared error train: 25656.76

# %%
df_metrics = df_metrics.append(pf.modelo_perceptron_multicapa(df),ignore_index=True)
# Out:
# Mean absolute error: 83.25
# Mean_absolute_error: 80.22
# Mean squared error: 12274.62
# Mean squared error: 10311.30

# %%
df_metrics = df_metrics.append(pf.modelo_perceptron_multicapa_sin_transformaciones(df),ignore_index=True )
# Out:
# Mean absolute error: 98.95
# Mean_absolute_error: 132.68
# Mean squared error: 14594.81
# Mean squared error: 26047.57

# %%
df_metrics = df_metrics.append(pf.model_arima(df),ignore_index=True )
# Out:
# Ingrese valor p para modelo ARIMA: 10
# Mean absolute error: 119.60
# Mean absolute error: 60.09
# Mean squared error: 18610.33
# Mean squared error: 5994.78

# %%
plt.figure(figsize=(18,7))
plt.bar(df_metrics.modelo, df_metrics.mae_test)
plt.ylabel('Error promedio')
plt.xlabel('Modelos')
plt.title('MAE modelos')
plt.show()
