# %%
# !pip install holidays
# !pip install holidays-co
# !pip install scikit-learn
# !pip install ipynb

# %%
import pronostic_functions as pf

# %%
df = pf.obtener_datos(input("Ingrese la ciudad sin tildes: "))
df
# Out:
# Ingrese la ciudad sin tildes: medellin
# None
# None
# None
#           fecha  servicios
# 0     1/04/2020        906
# 1     2/04/2020       1013
# 2     3/04/2020       1063
# 3     4/04/2020        953
# 4     5/04/2020        975
# ..          ...        ...
# 388  24/04/2021       1241
# 389  25/04/2021       1253
# 390  26/04/2021       1294
# 391  27/04/2021       1189
# 392  28/04/2021       1235
#
# [393 rows x 2 columns]

# %%
pf.model_arima(df, input("Ingresa el valor de p"), input("Ingresa el valor de q"))
# Out:
# Ingresa el valor de p2
# Ingresa el valor de q3
#                 0
# count  314.000000
# mean     2.303709
# std     95.858274
# min   -271.011714
# 25%    -62.494860
# 50%     -0.033435
# 75%     52.094585
# max    293.397172
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:              servicios   No. Observations:                  314
# Model:                     ARMA(2, 3)   Log Likelihood               -1877.020
# Method:                       css-mle   S.D. of innovations             95.270
# Date:                Wed, 19 May 2021   AIC                           3768.041
# Time:                        20:37:12   BIC                           3794.286
# Sample:                             0   HQIC                          3778.528
#
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            1144.0254     34.691     32.977      0.000    1076.032    1212.019
# ar.L1.servicios     1.6550      0.118     14.075      0.000       1.425       1.885
# ar.L2.servicios    -0.6665      0.116     -5.738      0.000      -0.894      -0.439
# ma.L1.servicios    -1.2199      0.114    -10.716      0.000      -1.443      -0.997
# ma.L2.servicios    -0.0972      0.111     -0.873      0.383      -0.316       0.121
# ma.L3.servicios     0.3961      0.055      7.181      0.000       0.288       0.504
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0387           +0.0000j            1.0387            0.0000
# AR.2            1.4444           +0.0000j            1.4444            0.0000
# MA.1            1.1075           -0.2357j            1.1323           -0.0334
# MA.2            1.1075           +0.2357j            1.1323            0.0334
# MA.3           -1.9694           -0.0000j            1.9694           -0.5000
# -----------------------------------------------------------------------------
# 129.81866670014614

# %%
pf.model_adaline(df)
# Out:
# Ingrese el valor p: 2

# %%
pf.modelo_perceptron_multicapa(df)
# Out:
# Ingrese el valor p: 2
# Mean absolute error: 86.36
# Mean squared error: 13035.26
# Variance score: 0.19

# %%
pf.modelo_perceptron_multicapa_sin_transformaciones(df, int(input('Ingrese valor p: ')))
# Out:
# Ingrese valor p: 14
# Mean absolute error: 117.56
# Mean_absolute_error: 117.56
# Mean squared error: 20429.83
# Mean squared error: 20429.83
# Variance score: -0.42
# Variance score: -0.42
