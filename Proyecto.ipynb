# %%
# !pip install scikit-learn
# !pip install ipynb

# %%
import pronostic_functions as pf

# %%
df = pf.obtener_datos(input("Ingrese la ciudad sin tildes: "))
df
# Out:
# Ingrese la ciudad sin tildes: medellin
# None
# None
# None
#           fecha  servicios
# 0     1/04/2020        906
# 1     2/04/2020       1013
# 2     3/04/2020       1063
# 3     4/04/2020        953
# 4     5/04/2020        975
# ..          ...        ...
# 388  24/04/2021       1241
# 389  25/04/2021       1253
# 390  26/04/2021       1294
# 391  27/04/2021       1189
# 392  28/04/2021       1235
#
# [393 rows x 2 columns]

# %%
pf.model_arima(df)
# Out:
# Ingrese valor p: 10
# Mean absolute error: 62.49
# Mean squared error: 6453.58
# Variance score: 0.59

# %%
pf.model_adaline(df)
# Out:
# Ingrese el valor p: 2

# %%
pf.modelo_perceptron_multicapa(df)
# Out:
# Ingrese el valor p: 2
# Mean absolute error: 86.36
# Mean squared error: 13035.26
# Variance score: 0.19

# %%
pf.modelo_perceptron_multicapa_sin_transformaciones(df)
# Out:
# Ingrese valor p: 2
# Mean absolute error: 100.41
# Mean_absolute_error: 100.41
# Mean squared error: 16116.39
# Mean squared error: 16116.39
# Variance score: -0.05
# Variance score: -0.05
