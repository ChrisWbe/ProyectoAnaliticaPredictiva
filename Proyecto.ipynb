# %%
# !pip install scikit-learn
# !pip install ipynb

# %%
import pronostic_functions as pf

# %%
df = pf.obtener_datos(input("Ingrese la ciudad sin tildes: "))
df
# Out:
# Ingrese la ciudad sin tildes: medellin
# None
# None
# None
#           fecha  servicios
# 0     1/04/2020        906
# 1     2/04/2020       1013
# 2     3/04/2020       1063
# 3     4/04/2020        953
# 4     5/04/2020        975
# ..          ...        ...
# 388  24/04/2021       1241
# 389  25/04/2021       1253
# 390  26/04/2021       1294
# 391  27/04/2021       1189
# 392  28/04/2021       1235
#
# [393 rows x 2 columns]

# %%
pf.model_arima(df)
# Out:
# Ingrese valor p: 2
# Mean absolute error: 74.12
# Mean squared error: 9697.22
# Variance score: 0.38

# %%
pf.model_adaline_optimizado(df)
# Out:
# Seleccione el número de inicio para probar P: 2
# Seleccione el número de fin para probar P: 4
# Con P = 2 el error abs promedio de entrenamiento: 130.27, y el error abs promedio de pronóstico: 87.84
# Con P = 3 el error abs promedio de entrenamiento: 128.89, y el error abs promedio de pronóstico: 83.63
# Con P = 4 el error abs promedio de entrenamiento: 127.19, y el error abs promedio de pronóstico: 81.28
# El P óptimo es: 4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-909e4c698a15> in <module>
# ----> 1 pf.model_adaline_optimizado(df)
#
# ~\Documents\ProyectoAnaliticaPredictiva\pronostic_functions.py in model_adaline_optimizado(df)
#     252       print("Con P = {} el error abs promedio de entrenamiento: {}, y el error abs promedio de pronóstico: {}".format(lm,EPE,EPF))
#     253   print("El P óptimo es: {}".format(popt))
# ...

# %%
pf.modelo_perceptron_multicapa(df)
# Out:
# Ingrese el valor p: 2
# Mean absolute error: 86.36
# Mean squared error: 13035.26
# Variance score: 0.19

# %%
pf.modelo_perceptron_multicapa_sin_transformaciones(df)
# Out:
# Ingrese valor p: 2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-5c4a16549b27> in <module>
# ----> 1 pf.modelo_perceptron_multicapa_sin_transformaciones(df)
#
# ~\Documents\ProyectoAnaliticaPredictiva\pronostic_functions.py in modelo_perceptron_multicapa_sin_transformaciones(df)
#     422
#     423     graficar_modelo()
# --> 424     computar_metricas()
#
# ~\Documents\ProyectoAnaliticaPredictiva\pronostic_functions.py in computar_metricas()
#     395         e_y_m1_test = y_m1[len(e_y_m1_train):]
#     396
# --> 397         print("Mean absolute error: %.2f" % mean_absolute_error(e_train, e_y_m1_train))
#     398         print("Mean_absolute_error: %.2f" % mean_absolute_error(df_test, e_y_m1_test))
#     399         print("Mean squared error: %.2f" % mean_squared_error(e_train, e_y_m1_train))# MSE
#
# ...
